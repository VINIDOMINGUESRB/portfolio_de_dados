# %% [markdown]
# # Em construção (...)

# %% [markdown]
# # Objetivo
# Este notebook tem como objetivo demonstrar um passo-a-passo de como capturar dados, fazer análises e ter insights sobre o Open Finance Brasil.
# Uso de dados abertos disponíveis no dashboard do cidadão (https://dashboard.openfinancebrasil.org.br/)
#
# # Passo a passo
#  - Consumo de APIS do Dashboard do cidadão;
#  - Construção de um dataset completo;
#  - Análises de dados com gráficos;
#  - Insights unindo o conhecimento do Tema com os dados apresentados;

# %%
import pandas as pd
import matplotlib.pyplot as plt
import json
import requests
import urllib3
from datetime import datetime, timedelta
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %%
def get_fridays_until_now (year=2023):
    start_date = datetime(year, 1, 1)
    first_friday = start_date + timedelta(days=(4 - start_date.weekday() + 7) % 7)
    fridays = []
    today = datetime.now()

    while first_friday <= today:
        fridays.append(first_friday.strftime('%Y-%m-%d'))
        first_friday += timedelta(days=7)

    return fridays
    
fridays = get_fridays_until_now()

print(fridays)
# Out:
# ['2023-01-06', '2023-01-13', '2023-01-20', '2023-01-27', '2023-02-03', '2023-02-10', '2023-02-17', '2023-02-24', '2023-03-03', '2023-03-10', '2023-03-17', '2023-03-24', '2023-03-31', '2023-04-07', '2023-04-14', '2023-04-21', '2023-04-28', '2023-05-05', '2023-05-12', '2023-05-19', '2023-05-26', '2023-06-02', '2023-06-09', '2023-06-16', '2023-06-23', '2023-06-30', '2023-07-07', '2023-07-14', '2023-07-21', '2023-07-28', '2023-08-04', '2023-08-11', '2023-08-18', '2023-08-25', '2023-09-01', '2023-09-08', '2023-09-15', '2023-09-22', '2023-09-29', '2023-10-06', '2023-10-13', '2023-10-20', '2023-10-27', '2023-11-03', '2023-11-10', '2023-11-17', '2023-11-24', '2023-12-01', '2023-12-08', '2023-12-15', '2023-12-22', '2023-12-29', '2024-01-05', '2024-01-12', '2024-01-19', '2024-01-26', '2024-02-02', '2024-02-09', '2024-02-16', '2024-02-23', '2024-03-01', '2024-03-08', '2024-03-15', '2024-03-22', '2024-03-29', '2024-04-05', '2024-04-12', '2024-04-19', '2024-04-26', '2024-05-03', '2024-05-10', '2024-05-17', '2024-05-24', '2024-05-31', '2024-06-07', '2024-06-14', '2024-06-21', '2024-06-28', '2024-07-05', '2024-07-12', '2024-07-19', '2024-07-26', '2024-08-02', '2024-08-09', '2024-08-16', '2024-08-23', '2024-08-30', '2024-09-06', '2024-09-13', '2024-09-20', '2024-09-27', '2024-10-04', '2024-10-11', '2024-10-18', '2024-10-25', '2024-11-01', '2024-11-08', '2024-11-15', '2024-11-22', '2024-11-29', '2024-12-06', '2024-12-13', '2024-12-20', '2024-12-27', '2025-01-03', '2025-01-10', '2025-01-17', '2025-01-24', '2025-01-31', '2025-02-07', '2025-02-14', '2025-02-21', '2025-02-28', '2025-03-07', '2025-03-14', '2025-03-21', '2025-03-28', '2025-04-04', '2025-04-11', '2025-04-18', '2025-04-25', '2025-05-02', '2025-05-09', '2025-05-16', '2025-05-23', '2025-05-30', '2025-06-06', '2025-06-13', '2025-06-20', '2025-06-27']

# %%
url_opf_participants = "https://data.directory.openbankingbrasil.org.br/participants"
response = requests.get(url_opf_participants)
data_opf_participants = response.json()
banks = {
    item.get("OrganisationName"): item.get("OrganisationId")
    for item in data_opf_participants
}
banks
# Out:
# {'UNIPRIME CENTRAL CCC LTDA.': '18543a69-338d-5e5b-8aa3-dc640ef5f4a2',
#  'ITAU CV S.A.': 'a773281f-9897-5e23-b422-ec72735f4f12',
#  'EFI S.A. - INSTITUICAO DE PAGAMENTO': 'b43131be-6a7f-5bfb-b436-c3ac5c5c2dac',
#  'CARTOS SCD S.A.': 'ea5f58d1-b363-58ef-9d09-46ae53398b5d',
#  'NU PAGAMENTOS S.A. - INSTITUICAO DE PAGAMENTO': '926e3037-a685-553c-afa3-f7cb46ff8084',
#  'PEFISA S.A. - CFI': 'aaa29038-e09c-5210-afe4-132750a6157c',
#  'ACCREDITO - SOCIEDADE DE CREDITO DIRETO S.A.': '12db6790-1ec9-4199-b20a-2820b7ec22c2',
#  'DOCK INSTITUICAO DE PAGAMENTO S.A.': 'b20c07c6-ec63-5add-bdef-e1023017f166',
#  'SANTANDER CCVM S.A.': '9f1959f0-5fa8-54c7-a978-329994ffe3bd',
#  'BCO BRADESCO FINANC. S.A.': '21d26a33-f1bc-5a9e-956c-0bfe048608da',
#  'MIDWAY S.A. - SCFI': '42609b73-82bc-5758-9c12-7e0bcc84885e',
#  'DLOCAL BRASIL INSTITUICAO DE PAGAMENTO S.A.': '2af3b0a1-b810-4e6d-95f0-95f1a9fd8097',
#  'INTRAG DTVM LTDA': '97a95ddb-a6ca-58ff-9551-c371ad20371a',
#  'PINBANK BRASIL INSTITUICAO DE PAGAMENTO S/A': 'd0190382-b93b-42a6-a007-da7fe8c97dba',
#  'TORO CTVM': '2ef309cb-7e91-44c5-a426-554fb972a9c2',
#  'PICPAY': 'c0f47d95-78e7-5f20-b0ea-ff8a75a44a76',
#  'IUGU INSTITUICAO DE PAGAMENTO S.A.': 'f1f45e74-57da-43d0-b246-fbb29e348661',
#  'UNAVANTI SOCIEDADE DE CREDITO DIRETO S/A': 'a1208e6c-6b4c-4720-8a63-2831862a4efd',
#  'AYMORE CFI S.A.': 'f83bee4f-26df-53d7-8335-a8a6edd7e340',
#  'BCO SANTANDER (BRASIL) S.A.': 'b8d20b1b-e8a7-5099-8174-05ea48bcb566',
#  'BANCO INVESTCRED UNIBANCO S.A.': '47f4815d-33d1-5b5c-a8f4-1eb45aaf7113',
#  'ASAAS GESTAO FINANCEIRA INSTITUICAO DE PAGAMENTO S.A.': '7e780f5a-c95e-4e5e-a4e7-66a4fa43dc6c',
#  'FINNET S/A - TECNOLOGIA E INSTITUICAO DE PAGAMENTO': '39bf5c68-08b7-4039-9fb3-b211792c5082',
#  'BCO INDUSTRIAL DO BRASIL S.A.': 'd6d2f28d-b019-506c-a438-b11fb1172812',
#  'MERCADO PAGO INSTITUICAO DE PAGAMENTO LTDA': 'e5a1c7ad-11d4-560d-914c-611003a39219',
#  'Z1 INSTITUICAO DE PAGAMENTO LTDA.': '81ac94e9-e7d9-4f96-8ab3-b8fd4661a26c',
#  'BANCO DO BRASIL S.A.': '9415f224-9f58-56b5-af4c-085b4438e4eb',
#  'BCO BMG S.A.': '4ae2cefb-e3c1-5624-9448-b3aa4777c539',
#  'PARANA BCO S.A.': '9cbed331-1e64-5d5a-84aa-fc64758993ab',
#  'GETNET ADQUIRENCIA E SERVICOS PARA MEIOS DE PAGAMENTO S A': '37069280-dd12-5475-b79e-2e434bb8db4b',
#  'BANCO BRADESCO SA': 'a72a6d4f-79be-5362-afb6-f8d9c9c39cf5',
#  'CORA SCD S.A.': '19f45346-a153-584d-b10f-3f57a20c4a75',
#  'SEFER INVESTIMENTOS DTVM LTDA': 'd718ef55-3d7d-4b2f-90be-5db12e91fbcd',
#  'LISTO SOCIEDADE DE CREDITO DIRETO S.A.': 'ca146165-ab58-4c91-b023-baedddbf9f16',
#  'BCO PAULISTA S.A.': '99aff3b0-5617-5fad-bc6e-66e320a217fc',
#  'BCO DO ESTADO DO RS S.A.': '2a01e202-e8f0-5f5a-9651-ebc257371e6e',
#  'FITBANK INSTITUICAO DE PAGAMENTOS ELETRONICOS S.A': '46efd0ae-a7d7-4858-a272-fa3790e16795',
#  'CENTRAL AILOS': 'f7817b3c-c319-575f-8896-727c1b12cfda',
#  'ACESSO SOLUCOES PAGAMENTO SA': 'e1d52399-a2a1-53be-a84b-085c1a94aac5',
#  'Banco Master S.A.': '1e6aeb44-8b00-5e2a-bcf7-e3db7f3b7e6f',
#  'CIELO S.A.': 'd96d6def-7f8f-5623-b15a-0bb5910920d1',
#  'BCO MERCANTIL DO BRASIL S.A.': '5d249486-c697-5295-a856-9955ed3ac332',
#  'LINA INSTITUICAO DE PAGAMENTO S.A': '0add85e7-086c-41d0-bd35-a3641d7acc36',
#  'BCO ITAUCARD S.A.': 'b6b68aba-7b89-5981-8679-28a4244df514',
#  'QI SCD S.A.': '30e4d3c0-f0a8-53b8-95d3-0af6b2ffddee',
#  'BCO AGIBANK S.A.': 'b6e68e03-c85d-54e8-8649-6e9bf9bb5dd8',
#  'BCO TRIANGULO S.A.': '357eb23b-f14d-5323-936d-f5b47dcb0eb6',
#  'REDECARD S.A.': 'c5845a52-3db6-540b-b0c1-a8c60bf59637',
#  'BCO DO EST. DE SE S.A.': '2d8829d2-4784-5a8a-9243-abd4a579000e',
#  'BANCO PAN': 'b6a214c7-6332-5a41-8464-a281fb9a4ca0',
#  'CREFISA S.A. CFI': '9294c0e8-ab01-5614-942d-97f261fe3454',
#  'LUIZACRED S.A. SCFI': '9001a505-f134-534b-aa67-57a462507c61',
#  'BRASIL CARD INSTITUICAO DE PAGAMENTOS LTDA': '713a6187-0765-43a8-8c08-df41c5cae389',
#  'CARUANA SCFI': '97b71d05-05bc-5f97-9097-1ae718b8b683',
#  'BCO SAFRA S.A.': '709138dd-6e9d-5f96-bfff-69a5b2cb3ec0',
#  'BCO GUANABARA S.A.': '611fbe39-0dc5-521f-8065-0fe780dd90e0',
#  'BCO ALFA S.A.': 'e0d17755-eb2b-539d-b90c-a765cdeefc2b',
#  'BCO XP S.A.': '79717d71-0cf4-58f6-b2d0-370d5404d383',
#  'BANCO SEMEAR': 'abad7f92-1528-5bbf-93fe-1e630e4cb913',
#  'STONE PAGAMENTOS S.A.': 'a3cec8d6-65b1-529d-bac5-9892d0c4efa3',
#  'UP.P SEP S.A.': 'e5b51083-adc2-5775-b0fc-02b263b1c40d',
#  'BANCO VOITER SA': 'b23de9c7-5c58-5ca2-867c-74cc65a2b435',
#  'Ebanx Instituicao de Pagamento Ltda.': '61d294e0-7dce-5ef3-97db-aebe989df40c',
#  'PAGSEGURO': '21f306af-5a9a-5dc6-a8f3-f56ff394e7be',
#  'BCO ABC BRASIL S.A.': '6029b5af-4c13-52ee-b33d-2bc9fd938bdd',
#  'BCO DA AMAZONIA S.A.': '9ff5e023-dcfe-595b-8be9-4a1b9c1597d6',
#  'CRYSTAL BMC - INSTITUICAO DE PAGAMENTO LTDA.': '294afb98-2089-4272-a6ba-88401c1baa45',
#  'BCO VOTORANTIM S.A.': '062c5edb-4e83-5002-9981-e2a96c5ad41e',
#  'UNIPRIME CENTRO-OESTE DO BRASIL CC': 'd30e4410-bd56-510d-8b75-7d8e85f1b138',
#  'BCO LOSANGO S.A.': 'ccdce1b1-79f4-5c42-8ba9-13cb23a18b71',
#  'BANCO HYUNDAI CAPITAL BRASIL': 'e5f4ae4a-9732-5a9d-86f6-31509e7dd46a',
#  'CONFEDERACAO DAS COOPERATIVAS DO SICREDI - CONFEDERACAO SICREDI': '0da3f6e5-a748-55d1-b39f-1653df146729',
#  'EMBRACRED S/A SOCIEDADE DE CREDITO DIRETO': '5403880c-21cf-4c5e-b2d3-6bb6e8d0a2a3',
#  'Blu Instituicao de Pagamento LTDA': '30941d17-8de3-4556-8163-1cfcb8e54a62',
#  'BCO BANESTES S.A.': '56d70da7-b73c-5b59-801a-54fb418e95ed',
#  'MONEY PLUS SCMEPP LTDA': 'f475af96-81d1-5a95-a656-f8a824bb84e3',
#  'SHOPEE': '96748716-9b96-448c-a2b7-2abf9762af8e',
#  'BCO RIBEIRAO PRETO S.A.': '52d0905b-0a8d-5fcb-a0d1-92ab96ab789e',
#  'SISPRIME DO BRASIL - COOPERATIVA DE CREDITO': 'b185ecfd-53b1-51ac-86bf-51d6cd66d828',
#  'SUMUP SCD S.A.': '50b67cd8-5f86-5f81-99b5-af83dae25c74',
#  'BCO ARBI S.A.': '65a9cfe4-b7a1-5b59-8e10-3ce0e271b0a5',
#  'PARATI - CFI S.A.': '3a5ea40d-b088-5118-ac8d-869964bfd67a',
#  'ITAÚ DTVM S.A.': '0e8dc735-25a6-5b66-b004-630c242a57cf',
#  'BCO ITAÚ BBA S.A.': '46f7ca95-cb75-5f0e-9ac6-5d06c3636ae0',
#  'Confederacao Nacional das Cooperativas do Sicoob': '777b3ece-75ea-5fa7-a464-dd29b141e99e',
#  'RECARGAPAY INSTITUICAO DE PAGAMENTO LTDA.': '63d4b5c5-1a5b-47a8-ac33-36609f934c87',
#  'BCO C6 S.A.': 'b024cf43-9ce6-52c4-8820-9b5d0bccb74c',
#  'BCO LA NACION ARGENTINA': '0e7f1342-d2bf-52f6-adbe-3f137aea9449',
#  'BCO SOFISA S.A.': 'bb3b0993-554d-5ea4-91ee-13af4ffe988d',
#  'BCO DO EST. DO PA S.A.': '0663f6ea-2dd2-5b19-9194-dda6763dca7f',
#  'CAIXA ECONOMICA FEDERAL': 'c160a6f5-e5df-5067-9e97-ec6fba62fd87',
#  'BRB - BCO DE BRASILIA S.A.': 'effb6cae-e6d6-5f0b-8f31-ee7922850300',
#  'ITAU UNIBANCO S.A.': '9c721898-9ce0-50f1-bf85-05075557850b',
#  'BANCO BRADESCARD': 'b2cf16dd-b545-5676-a8eb-76980bd72315',
#  'BCO RENDIMENTO S.A.': '3c13ff66-3972-5ce5-9e78-49cac18af52a',
#  'CONF NAC COOP CENTRAIS UNICRED': '3526aff7-18d3-52f9-9668-ddd4753ea09e',
#  'HUB PAGAMENTOS S.A': '7eebe017-cb01-498c-81e4-6b4149b18e93',
#  'FIN. ITAU CBD CFI': '2ff098d1-a482-5f68-8a12-b8f0109c4811',
#  'GERU SOCIEDADE DE CREDITO DIRETO': '0ca05092-025f-47c4-b878-4a03c150cccf',
#  'Neon Pagamentos': '6f86d2ab-8ef7-4a9b-8c5f-d081f183c490',
#  'OKTO INSTITUICAO DE PAGAMENTO S.A.': '23f9e3dd-31a1-4eaf-a440-37711ad34e81',
#  'ÁGORA CTVM S.A.': '0481f9fe-c01b-51c8-88d2-9a18d32b19b3',
#  'CELCOIN INSTITUICAO DE PAGAMENTO S.A.': 'c55ceb2e-c9fb-4989-8ed1-39208d6d7951',
#  'BCO RCI BRASIL S.A.': '67a8b715-9318-5a6d-b3cd-3d2e8f2b6cb8',
#  'BANCO GENIAL S.A.': '8292c33e-d95a-5fe7-8f27-dd7a95c68b55',
#  'BANCO DIGIO': '27aea8f6-2119-55f8-9553-5ad4b08eeb17',
#  'BANCO BTG PACTUAL S.A.': '0bd0b05e-ce18-5105-bbe9-ddf16a79eff9',
#  'BCO CITIBANK S.A.': 'df49c2b5-0de6-5a66-a05a-233f1d3cce65',
#  'BANCO INTER': '31ee4f72-8769-5136-83e4-03f2dd4c935e',
#  'BCO ITAUBANK S.A.': 'a3280c20-efe2-5634-907f-6ef2a42d2a7d',
#  'BCO DO NORDESTE DO BRASIL S.A.': 'a60b7fb5-f7f3-5536-a41f-1bff137f47d1',
#  'HIPERCARD BM S.A.': '8f25b949-de2d-59c2-967a-2f4ca924890e',
#  'BANCO ITAÚ CONSIGNADO S.A.': '2edb4cc0-8a11-5034-aadf-0f05878bdcc7',
#  'CRESOL CONFEDERAÇÃO': '7f1d4439-d1d5-5cf8-84a9-fd05305db9c2',
#  'QUERO-QUERO VERDECARD INSTITUICAO DE PAGAMENTO S.A.': '486dbae5-2466-4592-9f30-efe1af447903',
#  'CC UNIPRIME SUL MS': '1e8a43c5-b11b-5ca1-bf48-0c5632fcca8a',
#  'CRED SYSTEM SOCIEDADE DE CREDITO DIRETO SA': 'f1d2b054-dc92-4beb-9a9e-0a3607e8d3b7',
#  'BCO. J.SAFRA S.A.': 'a791c2f9-45f8-5218-9bfe-ab9c07abb398',
#  'WILL FINANCEIRA S.A. CREDITO, FINANCIAMENTO E INVESTIMENTO': '275e4816-b225-47be-a9c1-a5eb3d0d2969',
#  'Belvo Instituicao de Pagamento Ltda.': '5883e379-43b1-4184-8304-df32a018620e',
#  'Iniciador Instituicao de Pagamento Ltda': '0e5ae3f4-ad98-4b40-b603-d9fed2a5f89b',
#  'DELEND INSTITUICAO DE PAGAMENTO LTDA': '538e025b-79fb-4a44-8321-587a84f3bef9',
#  'PLUGGY BRASIL INSTITUICAO DE PAGAMENTO LTDA': '24651a57-42bc-4d94-88cd-8cacf03f8c49',
#  'MERCADO BITCOIN INSTITUICAO DE PAGAMENTO LTDA': 'a073c729-533f-43bc-a02c-976b65ceb4c9',
#  'PROVER PROMOCAO DE VENDAS INSTITUICAO DE PAGAMENTO LTDA': 'd3e65fbe-b355-4a77-bdf2-bbb8028c9a54',
#  '99PAY INSTITUICAO DE PAGAMENTO S.A.': '18a5f8fd-836e-4a7f-8db3-32d0c98da989',
#  'WE PAY OUT INSTITUICAO DE PAGAMENTO LTDA.': '6aa5161c-938d-4747-a4c8-75e8ffabdbb1',
#  'BANQI INSTITUICAO DE PAGAMENTO LTDA': '1dd7da04-b620-462c-9587-86391979bf57',
#  'CLOUDWALK INSTITUICAO DE PAGAMENTO E SERVICOS LTDA': 'fae29bd3-fac3-4f34-b2e1-139ba63f9440',
#  'J17 Sociedade de Credito Direto S.A.': 'ed159ebc-0757-4964-9b63-c2d52fe58674',
#  'PAGUEVELOZ INSTITUICAO DE PAGAMENTO LTDA': '01843746-0350-4758-8647-f8c9c5aa86d8',
#  'Swap Meios de Pagamentos Instituicao de Pagamento S.A.': '1a0cb96d-b634-4469-aab3-164ae3368ad2',
#  'TRIO INSTITUICAO DE PAGAMENTO LTDA.': '5e429123-0ee6-4ec0-96a8-c2e973a6070d',
#  'BANCO CSF S/A': 'c4bc3d73-a6a8-4376-ae28-8fbfa431916b',
#  'KLAVI INSTITUICAO DE PAGAMENTOS E GESTAO DE DADOS LTDA.': '63157678-2559-4c12-a1f8-859a278e408a'}

# %%
columns = ["value", "date"]

url = "https://dashboard.openfinancebrasil.org.br/api/consents"
df_actives_consents = pd.DataFrame(columns=columns)
for bank in banks:
    try:
        payload = json.dumps({
            "dates": fridays,
            "bank": banks[bank],
            "role":"client"
        })
        response = requests.post(url, data=payload, verify=False)
        response_data = response.json()
        df_bank = pd.DataFrame(response_data, columns=columns)
        df_bank["bank"] = bank
        df_actives_consents = pd.concat([df_actives_consents, df_bank], ignore_index=True)
    except Exception as e:
        print(f"Error processing bank {bank}: {e}")

df_actives_consents["date"] = pd.to_datetime(df_actives_consents["date"]).dt.date
df_actives_consents["qtt_active_consents"] = pd.to_numeric(df_actives_consents["value"], errors='coerce')
df_actives_consents = df_actives_consents.drop("value",axis=1)

# %%
df_actives_consents.head(5)
# Out:
#          date                        bank  qtt_active_consents
# 0  2023-01-06  UNIPRIME CENTRAL CCC LTDA.             21206242
# 1  2023-01-13  UNIPRIME CENTRAL CCC LTDA.             21910399
# 2  2023-01-20  UNIPRIME CENTRAL CCC LTDA.             22254725
# 3  2023-01-27  UNIPRIME CENTRAL CCC LTDA.             23359002
# 4  2023-02-03  UNIPRIME CENTRAL CCC LTDA.             23879579

# %%
columns = ["cpf","cnpj", "date"]
url = "https://dashboard.openfinancebrasil.org.br/api/unique-consents"
df_unique_consents = pd.DataFrame(columns=columns)

for bank in banks:
    try:
        payload = json.dumps({
            "dates": fridays,
            "bank": banks[bank],
            "role":"client"
        })
        response = requests.post(url, data=payload, verify=False)
        response_data = response.json()
        df_bank = pd.DataFrame(response_data, columns=columns)
        df_bank["bank"] = bank
        df_unique_consents = pd.concat([df_unique_consents, df_bank], ignore_index=True)
    except Exception as e:
        print(f"Error processing bank {bank}: {e}")
df_unique_consents["date"] = pd.to_datetime(df_unique_consents["date"]).dt.date
df_unique_consents["qtt_unique_personal_consents"] = pd.to_numeric(df_unique_consents["cpf"], errors='coerce')
df_unique_consents["qtt_unique_business_consents"] = pd.to_numeric(df_unique_consents["cnpj"], errors='coerce')
df_unique_consents = df_unique_consents.drop(["cpf", "cnpj"], axis=1)

# %%
df_unique_consents.head(5)
# Out:
#          date                        bank  qtt_unique_personal_consents  \
# 0  2023-01-06  UNIPRIME CENTRAL CCC LTDA.                      14328891
# 1  2023-01-13  UNIPRIME CENTRAL CCC LTDA.                      14559933
# 2  2023-01-20  UNIPRIME CENTRAL CCC LTDA.                      15002147
# 3  2023-01-27  UNIPRIME CENTRAL CCC LTDA.                      15467203
# 4  2023-02-03  UNIPRIME CENTRAL CCC LTDA.                      15861932
#
#    qtt_unique_business_consents
# 0                         72989
# 1                         75328
# 2                         77614
# 3                         80426
# 4                         83532

# %%
df_complete_consents = pd.merge(df_actives_consents, df_unique_consents, on=["date", "bank"], how="outer").fillna(0)
df_complete_consents
# Out:
#              date                                               bank  \
# 0      2023-01-06                         UNIPRIME CENTRAL CCC LTDA.
# 1      2023-01-13                         UNIPRIME CENTRAL CCC LTDA.
# 2      2023-01-20                         UNIPRIME CENTRAL CCC LTDA.
# 3      2023-01-27                         UNIPRIME CENTRAL CCC LTDA.
# 4      2023-02-03                         UNIPRIME CENTRAL CCC LTDA.
# ...           ...                                                ...
# 17140  2025-05-09  KLAVI INSTITUICAO DE PAGAMENTOS E GESTAO DE DA...
# 17141  2025-05-16  KLAVI INSTITUICAO DE PAGAMENTOS E GESTAO DE DA...
# 17142  2025-05-23  KLAVI INSTITUICAO DE PAGAMENTOS E GESTAO DE DA...
# 17143  2025-05-30  KLAVI INSTITUICAO DE PAGAMENTOS E GESTAO DE DA...
# 17144  2025-06-06  KLAVI INSTITUICAO DE PAGAMENTOS E GESTAO DE DA...
#
#        qtt_active_consents  qtt_unique_personal_consents  \
# 0                 21206242                      14328891
# 1                 21910399                      14559933
# 2                 22254725                      15002147
# 3                 23359002                      15467203
# 4                 23879579                      15861932
# ...                    ...                           ...
# 17140             81027623                      52232295
# 17141             82405542                      53088028
# 17142             83972335                      54972067
# 17143             85553006                      55919927
# 17144             86990193                      56843056
#
#        qtt_unique_business_consents
# 0                             72989
# 1                             75328
# 2                             77614
# 3                             80426
# 4                             83532
# ...                             ...
# 17140                        617447
# 17141                        626006
# 17142                        635503
# 17143                        644254
# 17144                        652421
#
# [17145 rows x 5 columns]
